# %%
"""
Select video files from LedaSila database, 
extract n frames per video and save to disc

Sign language video files copyright Alpen Adria Universität Klagenfurt 
http://ledasila.aau.at

Code based on:
https://github.com/harvitronix/five-video-classification-methods
"""
# Out:
# '\nSelect video files from LedaSila database, \nextract n frames per video and save to disc\n\nSign language video files copyright Alpen Adria Universität Klagenfurt \nhttp://ledasila.aau.at\n\nCode based on:\nhttps://github.com/harvitronix/five-video-classification-methods\n'

# %%
import numpy as np
import pandas as pd

import os
import glob

from subprocess import call

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline

# %%
# number of frames per video fixed upfront
nFrames_Video = 20

# %%
# Read all available videos in a dataframe

# %%
dfFiles = pd.DataFrame(glob.glob("../data/01-ledasila/**", recursive=True), dtype=str, columns=["sPath"])

# %%
dfFiles.head()
# Out:
#                                                sPath
# 0                               ../data/01-ledasila/
# 1                           ../data/01-ledasila/_tar
# 2        ../data/01-ledasila/_tar/ÖGS Gebärden.tar
# 3                              ../data/01-ledasila/r
# 4  ../data/01-ledasila/r/Ringen---k---vid-77479--...

# %%
# extract file names
dfFiles["sFile"] = dfFiles.sPath.apply(lambda s: s.split("/")[-1])
#dfFiles.head()

# %%
# drop files/folders without extension
dfFiles.loc[dfFiles.sFile.apply(lambda s: len(s.split("."))<=1),:] = None
dfFiles.dropna(inplace=True)
#dfFiles.head()

# %%
# only retain mp4 files
dfFiles.loc[dfFiles.sFile.apply(lambda s: s.split(".")[1] != "mp4"),:] = None
dfFiles.dropna(inplace=True)
#dfFiles.head()

# %%
# extract word
dfFiles["sWord"] = dfFiles.sFile.apply(lambda s: s.split("-")[0])
dfFiles.head()
# Out:
#                                                sPath  \
# 4  ../data/01-ledasila/r/Ringen---k---vid-77479--...
# 5  ../data/01-ledasila/r/Rote__R_uebe---ogs---vid...
# 6  ../data/01-ledasila/r/reden---k---vid-76401---...
# 7  ../data/01-ledasila/r/rauchen---ogs---vid-2697...
# 8  ../data/01-ledasila/r/riechen---s---vid-76597-...
#
#                                              sFile         sWord
# 4          Ringen---k---vid-77479---lsid-46634.mp4        Ringen
# 5  Rote__R_uebe---ogs---vid-27931---lsid-29402.mp4  Rote__R_uebe
# 6           reden---k---vid-76401---lsid-46120.mp4         reden
# 7       rauchen---ogs---vid-26975---lsid-28269.mp4       rauchen
# 8         riechen---s---vid-76597---lsid-46215.mp4       riechen

# %%
print("%d videos, with %d unique words" % (dfFiles.shape[0], dfFiles.sWord.unique().shape[0]))
# Out:
# 33308 videos, with 15684 unique words

# %%
# select videos with min n occurences
dfWord_freq = dfFiles.groupby("sWord").size().sort_values(ascending=False).reset_index(name="nCount")

nMinOccur = 18
dfWord_top = dfWord_freq.loc[dfWord_freq.nCount >= nMinOccur, :]
dfWord_top
# Out:
#             sWord  nCount
# 0            nein      34
# 1     schw_aermen      27
# 2             was      25
# 3            wann      24
# 4           nicht      22
# 5          fertig      22
# 6              ja      21
# 7          Banane      20
# 8        Motorrad      20
# 9         Fenster      20
# 10            Oma      20
# 11       Dezember      19
# 12   Schlafzimmer      19
# 13  Schildkr_oete      19
# 14     Nachmittag      19
# 15  K_uehlschrank      19
# 16           Herd      18
# 17         Himmel      18
# 18       Computer      18
# 19           Loch      18
# 20       schlagen      18

# %%
dfVideos = pd.merge(dfFiles, dfWord_top, how="right", on="sWord")

# %%
print("%d videos, %d unique words, min %d occurences" % 
      (dfVideos.shape[0], dfVideos.sWord.unique().shape[0], dfWord_top.nCount.min()))
# Out:
# 440 videos, 21 unique words, min 18 occurences

# %%
dfVideos.sample(5)
# Out:
#                                                  sPath  \
# 272  ../data/01-ledasila/m/Motorrad---s---vid-34801...
# 23   ../data/01-ledasila/n/nicht---t-ogs---vid-1512...
# 429  ../data/01-ledasila/w/was---v---vid-12877---ls...
# 282  ../data/01-ledasila/j/ja---ooe---vid-10589---l...
# 439  ../data/01-ledasila/w/was---w---vid-12875---ls...
#
#                                          sFile     sWord  nCount
# 272  Motorrad---s---vid-34801---lsid-17690.mp4  Motorrad      20
# 23    nicht---t-ogs---vid-1512---lsid-4755.mp4     nicht      22
# 429       was---v---vid-12877---lsid-17075.mp4       was      25
# 282      ja---ooe---vid-10589---lsid-14652.mp4        ja      21
# 439       was---w---vid-12875---lsid-17074.mp4       was      25

# %%
# test ffmpeg on one video

#seVideo = dfVideos.loc[0,:]
#print(os.getcwd())
#print(seVideo.sPath)
#call(["ffmpeg", "-i", seVideo.sPath, "-frames", "30", "../data/10-frames/Nachmittag---Oô-UK---vid-41601---lsid-34163/frame-%04d.jpg"])
# Out:
# /Users/Frederik/Dev/sign-language/02-leadsila
# ../data/01-ledasila/n/Nachmittag---Oô-UK---vid-41601---lsid-34163.mp4
# 0

# %%
# extract frames from each video
for pos, seVideo in dfVideos.iterrows():
    
    # for each video create separate directory in 10-frames
    sDir = os.path.join("../data/10-frames", seVideo.sFile.split(".")[0])
    if not os.path.exists(sDir):
        os.mkdir(sDir)
    dfVideos.loc[pos, "sPathFrames"] = sDir
    
    # call ffmpeg to extract frames from videos
    sFrames = os.path.join(sDir, "frame-%04d.jpg")
    #print(sFrames)
    call(["ffmpeg", "-i", seVideo.sPath, "-frames", str(nFrames_Video), sFrames])

# %%
# Extract InceptionV3 features from all frames and save to file

# %%
# get the InceptionV3 model
from cnninception import InceptionV3_features

cnn = InceptionV3_features()
# Out:
# /Users/Frederik/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# feed all frames into cnn, save results in file per video
for pos, seVideo in dfVideos.iterrows():
    
    print("Extracting features from", seVideo.sFile)
    # retrieve frame files
    sFrames = glob.glob(os.path.join(seVideo.sPathFrames, "*.jpg"))
    
    # run cnn on each frame, collect the resulting features
    liFeatures = []
    for sFrame in sFrames:
        features = cnn.extract(sFrame)
        liFeatures.append(features)
    
    # save resulting list of features in file in "data/20-features"
    sFeatures = os.path.join("../data/20-features", seVideo.sFile.split(".")[0] + \
                             "-" + str(nFrames_Video) + "features")
    np.save(sFeatures, liFeatures)
# Out:
# Extracting features from Nachmittag---Oô-UK---vid-41601---lsid-34163.mp4
# Extracting features from Nachmittag---k---vid-14232---lsid-17843.mp4
# Extracting features from Nachmittag---st---vid-14227---lsid-17841.mp4
# Extracting features from Nachmittag---w---vid-19534---lsid-20522.mp4
# Extracting features from Nachmittag---ooe---vid-14729---lsid-18092.mp4
# Extracting features from Nachmittag---v---vid-14226---lsid-17839.mp4
# Extracting features from Nachmittag---k---vid-66331---lsid-42446.mp4
# Extracting features from Nachmittag---w---vid-42507---lsid-31082.mp4
# Extracting features from Nachmittag---w---vid-14741---lsid-18098.mp4
# Extracting features from Nachmittag---ogs---vid-28973---lsid-29926.mp4
# Extracting features from Nachmittag---k---vid-14233---lsid-17844.mp4
# Extracting features from Nachmittag---w---vid-14223---lsid-17840.mp4
# Extracting features from Nachmittag---b---vid-19530---lsid-20520.mp4
# Extracting features from Nachmittag---s-k---vid-14235---lsid-17845.mp4
# Extracting features from Nachmittag---k---vid-19532---lsid-20521.mp4
# Extracting features from Nachmittag---noe-w---vid-14230---lsid-17842.mp4
# Extracting features from Nachmittag---t---vid-14740---lsid-18097.mp4
# Extracting features from Nachmittag---w---vid-14743---lsid-18099.mp4
# Extracting features from Nachmittag---t---vid-19561---lsid-20588.mp4
# Extracting features from nicht---ooe---vid-63706---lsid-42005.mp4
# Extracting features from nicht---w---vid-14784---lsid-18122.mp4
# Extracting features from nicht---t-ooe---vid-14511---lsid-17986.mp4
# Extracting features from nicht---s---vid-14519---lsid-17990.mp4
# Extracting features from nicht---t-ogs---vid-1512---lsid-4755.mp4
# Extracting features from nicht---v---vid-58438---lsid-17988.mp4
# Extracting features from nicht---ogs---vid-24596---lsid-26925.mp4
# Extracting features from nicht---t---vid-1514---lsid-4757.mp4
# Extracting features from nicht---w---vid-14785---lsid-18123.mp4
# Extracting features from nicht---ooe---vid-14523---lsid-17992.mp4
# Extracting features from nicht---k-ogs---vid-14527---lsid-17994.mp4
# Extracting features from nicht---noe---vid-14525---lsid-17993.mp4
# Extracting features from nicht---v---vid-14505---lsid-17983.mp4
# Extracting features from nicht---st---vid-14510---lsid-17985.mp4
# Extracting features from nicht---k---vid-50268---lsid-37679.mp4
# Extracting features from nicht---w---vid-14507---lsid-17984.mp4
# Extracting features from nicht---Stmk_UK---vid-72784---lsid-44435.mp4
# Extracting features from nicht---v---vid-63712---lsid-42008.mp4
# Extracting features from nicht---ooe-k---vid-14513---lsid-17987.mp4
# Extracting features from nicht---st---vid-63710---lsid-42007.mp4
# Extracting features from nicht---v---vid-14517---lsid-17989.mp4
# Extracting features from nicht---w---vid-14522---lsid-17991.mp4
# Extracting features from nein---Oô-UK---vid-41623---lsid-34173.mp4
# Extracting features from nein---w---vid-14775---lsid-18118.mp4
# Extracting features from nein---w---vid-14421---lsid-17940.mp4
# Extracting features from nein---v---vid-14409---lsid-17934.mp4
# Extracting features from nein---t---vid-1500---lsid-4730.mp4
# Extracting features from nein---s---vid-11621---lsid-15276.mp4
# Extracting features from nein---w---vid-14773---lsid-18117.mp4
# Extracting features from nein---s---vid-14402---lsid-17930.mp4
# Extracting features from nein---Stmk_UK---vid-72780---lsid-44433.mp4
# Extracting features from nein---ooe---vid-14574---lsid-18017.mp4
# Extracting features from nein---ooe---vid-15523---lsid-16185.mp4
# Extracting features from nein---ooe---vid-11623---lsid-15277.mp4
# Extracting features from nein---st---vid-14405---lsid-17932.mp4
# Extracting features from nein---t-s-st---vid-15528---lsid-16187.mp4
# Extracting features from nein---v---vid-14399---lsid-17929.mp4
# Extracting features from nein---ooe---vid-11615---lsid-15273.mp4
# Extracting features from nein---w---vid-35489---lsid-16184.mp4
# Extracting features from nein---noe---vid-14408---lsid-17933.mp4
# Extracting features from nein---w---vid-14403---lsid-17931.mp4
# Extracting features from nein---t---vid-2566---lsid-4155.mp4
# Extracting features from nein---st---vid-11627---lsid-15279.mp4
# Extracting features from nein---w---vid-58436---lsid-40449.mp4
# Extracting features from nein---k---vid-15525---lsid-16186.mp4
# Extracting features from nein---ogs---vid-28155---lsid-29530.mp4
# Extracting features from nein---v---vid-58434---lsid-16183.mp4
# Extracting features from nein---v---vid-11619---lsid-15275.mp4
# Extracting features from nein---noe---vid-14426---lsid-17942.mp4
# Extracting features from nein---s---vid-14418---lsid-17938.mp4
# Extracting features from nein---s---vid-11613---lsid-15272.mp4
# Extracting features from nein---ooe---vid-14423---lsid-17941.mp4
# Extracting features from nein---ogs---vid-31222---lsid-30531.mp4
# Extracting features from nein---s---vid-14414---lsid-17936.mp4
# Extracting features from nein---noe-k---vid-11625---lsid-15278.mp4
# Extracting features from nein---st-k---vid-11617---lsid-15274.mp4
# Extracting features from schlagen---t-s-k-ogs---vid-37023---lsid-32030.mp4
# Extracting features from schlagen---k---vid-59429---lsid-40807.mp4
# Extracting features from schlagen---t-s---vid-55475---lsid-39746.mp4
# Extracting features from schlagen---OÖ-UK---vid-41091---lsid-33912.mp4
# Extracting features from schlagen---ooe---vid-59453---lsid-40815.mp4
# Extracting features from schlagen---s---vid-49455---lsid-37327.mp4
# Extracting features from schlagen---k---vid-59433---lsid-40810.mp4
# Extracting features from schlagen---w---vid-63851---lsid-42071.mp4
# Extracting features from schlagen---t---vid-55477---lsid-39747.mp4
# Extracting features from schlagen---s-st---vid-49453---lsid-37326.mp4
# Extracting features from schlagen---ooe---vid-63853---lsid-42072.mp4
# Extracting features from schlagen---w---vid-59455---lsid-40816.mp4
# Extracting features from schlagen---k---vid-76962---lsid-46391.mp4
# Extracting features from schlagen---w---vid-63754---lsid-42028.mp4
# Extracting features from schlagen---v---vid-55976---lsid-39970.mp4
# Extracting features from schlagen---b---vid-63855---lsid-42073.mp4
# Extracting features from schlagen---k---vid-63857---lsid-42074.mp4
# Extracting features from schlagen---noe---vid-59444---lsid-40812.mp4
# Extracting features from Schlafzimmer---s---vid-49451---lsid-37325.mp4
# Extracting features from Schlafzimmer---s---vid-59391---lsid-40793.mp4
# Extracting features from Schlafzimmer---ooe---vid-59395---lsid-40795.mp4
# Extracting features from Schlafzimmer---w---vid-63841---lsid-42066.mp4
# Extracting features from Schlafzimmer---ooe---vid-63843---lsid-42067.mp4
# Extracting features from Schlafzimmer---w---vid-59387---lsid-40791.mp4
# Extracting features from Schlafzimmer---v---vid-59385---lsid-40790.mp4
# Extracting features from Schlafzimmer---st---vid-59393---lsid-40794.mp4
# Extracting features from Schlafzimmer---v---vid-55972---lsid-39968.mp4
# Extracting features from Schlafzimmer---t---vid-55472---lsid-39745.mp4
# Extracting features from Schlafzimmer---ogs---vid-31342---lsid-30593.mp4
# Extracting features from Schlafzimmer---w---vid-63752---lsid-42027.mp4
# Extracting features from Schlafzimmer---st---vid-53600---lsid-39064.mp4
# Extracting features from Schlafzimmer---k---vid-51009---lsid-37967.mp4
# Extracting features from Schlafzimmer---t---vid-61689---lsid-40792.mp4
# Extracting features from Schlafzimmer---v---vid-55974---lsid-39969.mp4
# Extracting features from Schlafzimmer---noe---vid-59397---lsid-40796.mp4
# Extracting features from Schlafzimmer---k---vid-63845---lsid-42069.mp4
# Extracting features from Schlafzimmer---b---vid-63847---lsid-42068.mp4
# Extracting features from schw_aermen---v---vid-15185---lsid-18356.mp4
# Extracting features from schw_aermen---noe---vid-15181---lsid-18351.mp4
# Extracting features from schw_aermen---k---vid-15140---lsid-18324.mp4
# Extracting features from schw_aermen---w---vid-15216---lsid-18371.mp4
# Extracting features from schw_aermen---k---vid-15189---lsid-18357.mp4
# Extracting features from schw_aermen---k---vid-15191---lsid-18358.mp4
# Extracting features from schw_aermen---t-s---vid-2774---lsid-4283.mp4
# Extracting features from schw_aermen---ooe---vid-33367---lsid-18355.mp4
# Extracting features from schw_aermen---k---vid-15155---lsid-18332.mp4
# Extracting features from schw_aermen---k---vid-15203---lsid-18365.mp4
# Extracting features from schw_aermen---w---vid-15217---lsid-18372.mp4
# Extracting features from schw_aermen---st---vid-15205---lsid-18366.mp4
# Extracting features from schw_aermen---noe---vid-15184---lsid-18352.mp4
# Extracting features from schw_aermen---w---vid-15207---lsid-18367.mp4
# Extracting features from schw_aermen---t-s---vid-2772---lsid-4282.mp4
# Extracting features from schw_aermen---ogs---vid-21093---lsid-23640.mp4
# Extracting features from schw_aermen---w---vid-15193---lsid-18359.mp4
# Extracting features from schw_aermen---k---vid-15197---lsid-18363.mp4
# Extracting features from schw_aermen---v---vid-15210---lsid-18368.mp4
# Extracting features from schw_aermen---t-s---vid-2770---lsid-4281.mp4
# Extracting features from schw_aermen---k---vid-15152---lsid-18330.mp4
# Extracting features from schw_aermen---ooe---vid-15211---lsid-18369.mp4
# Extracting features from schw_aermen---k---vid-15201---lsid-18364.mp4
# Extracting features from schw_aermen---st---vid-15213---lsid-18370.mp4
# Extracting features from schw_aermen---k---vid-15153---lsid-18331.mp4
# Extracting features from schw_aermen---v---vid-15195---lsid-18360.mp4
# Extracting features from schw_aermen---k---vid-15199---lsid-18362.mp4
# Extracting features from Schildkr_oete---k---vid-58995---lsid-40669.mp4
# Extracting features from Schildkr_oete---v---vid-59088---lsid-40700.mp4
# Extracting features from Schildkr_oete---t---vid-61683---lsid-40699.mp4
# Extracting features from Schildkr_oete---OÖ-UK---vid-41097---lsid-33915.mp4
# Extracting features from Schildkr_oete---ooe---vid-59005---lsid-40673.mp4
# Extracting features from Schildkr_oete---st---vid-59015---lsid-40676.mp4
# Extracting features from Schildkr_oete---w-ogs---vid-24823---lsid-28308.mp4
# Extracting features from Schildkr_oete---b---vid-58991---lsid-40667.mp4
# Extracting features from Schildkr_oete---OÖ-UK---vid-41099---lsid-33916.mp4
# Extracting features from Schildkr_oete---k---vid-58997---lsid-40670.mp4
# Extracting features from Schildkr_oete---v---vid-55970---lsid-39967.mp4
# Extracting features from Schildkr_oete---s---vid-49449---lsid-37324.mp4
# Extracting features from Schildkr_oete---st---vid-51289---lsid-38084.mp4
# Extracting features from Schildkr_oete---ooe---vid-58949---lsid-40657.mp4
# Extracting features from Schildkr_oete---t---vid-55457---lsid-39739.mp4
# Extracting features from Schildkr_oete---w---vid-58944---lsid-40652.mp4
# Extracting features from Schildkr_oete---OÖ-UK---vid-41095---lsid-33914.mp4
# Extracting features from Schildkr_oete---noe---vid-58999---lsid-40671.mp4
# Extracting features from Schildkr_oete---s---vid-59081---lsid-40698.mp4
# Extracting features from fertig---ogs---vid-28691---lsid-29796.mp4
# Extracting features from fertig---noe---vid-9643---lsid-15888.mp4
# Extracting features from fertig---noe---vid-9640---lsid-15887.mp4
# Extracting features from fertig---ooe-s-st-k---vid-2688---lsid-4232.mp4
# Extracting features from fertig---ooe---vid-33194---lsid-12548.mp4
# Extracting features from fertig---w---vid-9264---lsid-12488.mp4
# Extracting features from fertig---w---vid-1013---lsid-3373.mp4
# Extracting features from fertig---ooe---vid-9281---lsid-12496.mp4
# Extracting features from fertig---v---vid-9258---lsid-12484.mp4
# Extracting features from fertig---ooe---vid-9388---lsid-12549.mp4
# Extracting features from fertig---w---vid-9260---lsid-12486.mp4
# Extracting features from fertig---t---vid-33198---lsid-4241.mp4
# Extracting features from fertig---w---vid-33196---lsid-3394.mp4
# Extracting features from fertig---k---vid-528---lsid-1860.mp4
# Extracting features from fertig---Stmk_UK---vid-77840---lsid-44306.mp4
# Extracting features from fertig---t---vid-2687---lsid-4231.mp4
# Extracting features from fertig---k---vid-33190---lsid-12497.mp4
# Extracting features from fertig---v-k---vid-9256---lsid-12485.mp4
# Extracting features from fertig---w---vid-9266---lsid-12489.mp4
# Extracting features from fertig---OÖ-UK---vid-41828---lsid-34274.mp4
# Extracting features from fertig---w---vid-33192---lsid-12504.mp4
# Extracting features from fertig---s---vid-33200---lsid-4242.mp4
# Extracting features from Fenster---s---vid-70688---lsid-43732.mp4
# Extracting features from Fenster---st---vid-73476---lsid-44751.mp4
# Extracting features from Fenster---s-ogs---vid-31364---lsid-30604.mp4
# Extracting features from Fenster---t-s-k---vid-2664---lsid-4219.mp4
# Extracting features from Fenster---st---vid-9270---lsid-12491.mp4
# Extracting features from Fenster---w---vid-9184---lsid-12440.mp4
# Extracting features from Fenster---b---vid-9192---lsid-12444.mp4
# Extracting features from Fenster---ooe---vid-9268---lsid-12490.mp4
# Extracting features from Fenster---w---vid-9190---lsid-12443.mp4
# Extracting features from Fenster---noe-w---vid-1009---lsid-3320.mp4
# Extracting features from Fenster---st---vid-73478---lsid-44752.mp4
# Extracting features from Fenster---ooe---vid-9262---lsid-12487.mp4
# Extracting features from Fenster---noe---vid-9636---lsid-15885.mp4
# Extracting features from Fenster---OÖ-UK---vid-41822---lsid-34271.mp4
# Extracting features from Fenster---w---vid-9186---lsid-12441.mp4
# Extracting features from Fenster---v---vid-20503---lsid-22912.mp4
# Extracting features from Fenster---w---vid-9188---lsid-12442.mp4
# Extracting features from Fenster---s---vid-47278---lsid-4220.mp4
# Extracting features from Fenster---v-k---vid-9272---lsid-12492.mp4
# Extracting features from Fenster---k---vid-37712---lsid-12445.mp4
# Extracting features from Oma---ooe---vid-16886---lsid-18544.mp4
# Extracting features from Oma---OÖ-UK---vid-40869---lsid-33805.mp4
# Extracting features from Oma---t---vid-2632---lsid-4200.mp4
# Extracting features from Oma---k---vid-16879---lsid-18541.mp4
# Extracting features from Oma---ogs---vid-26673---lsid-28765.mp4
# Extracting features from Oma---t---vid-54875---lsid-39609.mp4
# Extracting features from Oma---b-k---vid-16887---lsid-18547.mp4
# Extracting features from Oma---w---vid-16889---lsid-18548.mp4
# Extracting features from Oma---v---vid-16871---lsid-18533.mp4
# Extracting features from Oma---st---vid-16445---lsid-20804.mp4
# Extracting features from Oma---st---vid-16875---lsid-18537.mp4
# Extracting features from Oma---Stmk_UK---vid-72800---lsid-44443.mp4
# Extracting features from Oma---s---vid-16873---lsid-18534.mp4
# Extracting features from Oma---t---vid-16709---lsid-21058.mp4
# Extracting features from Oma---noe-w---vid-16877---lsid-18539.mp4
# Extracting features from Oma---w---vid-23439---lsid-20880.mp4
# Extracting features from Oma---w---vid-19350---lsid-20297.mp4
# Extracting features from Oma---k---vid-45219---lsid-18543.mp4
# Extracting features from Oma---v---vid-16708---lsid-21057.mp4
# Extracting features from Oma---w---vid-21865---lsid-21257.mp4
# Extracting features from Herd---w---vid-46065---lsid-36005.mp4
# Extracting features from Herd---ogs---vid-46255---lsid-24189.mp4
# Extracting features from Herd---ooe---vid-7736---lsid-13558.mp4
# Extracting features from Herd---s-b---vid-7732---lsid-13555.mp4
# Extracting features from Herd---v---vid-42503---lsid-22941.mp4
# Extracting features from Herd---w---vid-7730---lsid-13554.mp4
# Extracting features from Herd---k---vid-46039---lsid-35993.mp4
# Extracting features from Herd---k---vid-76722---lsid-46276.mp4
# Extracting features from Herd---ogs---vid-46253---lsid-30645.mp4
# Extracting features from Herd---k---vid-7734---lsid-13556.mp4
# Extracting features from Herd---t---vid-46053---lsid-35999.mp4
# Extracting features from Herd---noe---vid-46045---lsid-35996.mp4
# Extracting features from Herd---k---vid-46035---lsid-35991.mp4
# Extracting features from Herd---s---vid-48192---lsid-36814.mp4
# Extracting features from Herd---st---vid-20518---lsid-22919.mp4
# Extracting features from Herd---t---vid-20515---lsid-22918.mp4
# Extracting features from Herd---v---vid-46061---lsid-36003.mp4
# Extracting features from Herd---w---vid-7728---lsid-13553.mp4
# Extracting features from Himmel---v-s-st---vid-46215---lsid-36075.mp4
# Extracting features from Himmel---w---vid-8344---lsid-13917.mp4
# Extracting features from Himmel---w---vid-46221---lsid-36078.mp4
# Extracting features from Himmel---t---vid-46217---lsid-36076.mp4
# Extracting features from Himmel---st---vid-18890---lsid-19935.mp4
# Extracting features from Himmel---ogs---vid-34446---lsid-31387.mp4
# Extracting features from Himmel---t---vid-18911---lsid-19937.mp4
# Extracting features from Himmel---OÖ-UK---vid-42364---lsid-34511.mp4
# Extracting features from Himmel---noe---vid-46213---lsid-36074.mp4
# Extracting features from Himmel---ooe---vid-8384---lsid-13921.mp4
# Extracting features from Himmel---w---vid-46219---lsid-36077.mp4
# Extracting features from Himmel---k---vid-46209---lsid-36072.mp4
# Extracting features from Himmel---k---vid-46211---lsid-36073.mp4
# Extracting features from Himmel---k---vid-8374---lsid-13920.mp4
# Extracting features from Himmel---w---vid-8354---lsid-13918.mp4
# Extracting features from Himmel---s---vid-48196---lsid-36816.mp4
# Extracting features from Himmel---w-b---vid-8364---lsid-13919.mp4
# Extracting features from Himmel---v---vid-18900---lsid-19936.mp4
# Extracting features from Motorrad---s---vid-11367---lsid-15071.mp4
# Extracting features from Motorrad---t---vid-11365---lsid-15070.mp4
# Extracting features from Motorrad---ooe---vid-19440---lsid-20384.mp4
# Extracting features from Motorrad---ogs---vid-34803---lsid-6006.mp4
# Extracting features from Motorrad---k---vid-22798---lsid-22320.mp4
# Extracting features from Motorrad---st---vid-58770---lsid-37869.mp4
# Extracting features from Motorrad---ooe---vid-13973---lsid-17693.mp4
# Extracting features from Motorrad---w---vid-2572---lsid-4158.mp4
# Extracting features from Motorrad---v---vid-13965---lsid-17689.mp4
# Extracting features from Motorrad---OÖ-UK---vid-41589---lsid-34157.mp4
# Extracting features from Motorrad---w---vid-13969---lsid-17691.mp4
# Extracting features from Motorrad---t---vid-2574---lsid-4159.mp4
# Extracting features from Motorrad---b-k---vid-19442---lsid-20385.mp4
# Extracting features from Motorrad---t---vid-19445---lsid-20386.mp4
# Extracting features from Motorrad---k---vid-11369---lsid-15072.mp4
# Extracting features from Motorrad---st---vid-13971---lsid-17692.mp4
# Extracting features from Motorrad---s---vid-34801---lsid-17690.mp4
# Extracting features from Motorrad---k---vid-13977---lsid-17695.mp4
# Extracting features from Motorrad---noe---vid-13975---lsid-17694.mp4
# Extracting features from Motorrad---ooe-w-v-st---vid-11363---lsid-15069.mp4
# Extracting features from ja---v-k---vid-10591---lsid-14653.mp4
# Extracting features from ja---Stmk_UK---vid-72618---lsid-44352.mp4
# Extracting features from ja---s---vid-10601---lsid-14658.mp4
# Extracting features from ja---noe-w---vid-64344---lsid-42298.mp4
# Extracting features from ja---t---vid-171---lsid-3865.mp4
# Extracting features from ja---t---vid-179---lsid-3874.mp4
# Extracting features from ja---ooe---vid-10589---lsid-14652.mp4
# Extracting features from ja---ooe---vid-10595---lsid-14655.mp4
# Extracting features from ja---v---vid-10599---lsid-14657.mp4
# Extracting features from ja---st-k---vid-10585---lsid-14650.mp4
# Extracting features from ja---s---vid-10593---lsid-14654.mp4
# Extracting features from ja---v-k---vid-10597---lsid-14656.mp4
# Extracting features from ja---OÖ-UK---vid-41252---lsid-33991.mp4
# Extracting features from ja---w---vid-169---lsid-3864.mp4
# Extracting features from ja---w-st---vid-10583---lsid-14649.mp4
# Extracting features from ja---v---vid-10581---lsid-14648.mp4
# Extracting features from ja---s---vid-10587---lsid-14651.mp4
# Extracting features from ja---w---vid-177---lsid-3873.mp4
# Extracting features from ja---w-st---vid-173---lsid-3868.mp4
# Extracting features from ja---t---vid-175---lsid-3872.mp4
# Extracting features from ja---ogs---vid-25433---lsid-27525.mp4
# Extracting features from Computer---k---vid-4000---lsid-10520.mp4
# Extracting features from Computer---k---vid-2828---lsid-11791.mp4
# Extracting features from Computer---Leonardo---vid-11449---lsid-15140.mp4
# Extracting features from Computer---Stmk_UK---vid-72480---lsid-44284.mp4
# Extracting features from Computer---ooe-k---vid-3998---lsid-10519.mp4
# Extracting features from Computer---t---vid-15158---lsid-18333.mp4
# Extracting features from Computer---w---vid-3992---lsid-10516.mp4
# Extracting features from Computer---ogs---vid-20918---lsid-23468.mp4
# Extracting features from Computer---OÖ-UK---vid-41186---lsid-33958.mp4
# Extracting features from Computer---w---vid-3996---lsid-10518.mp4
# Extracting features from Computer---s---vid-3990---lsid-10515.mp4
# Extracting features from Computer---v---vid-3380---lsid-10024.mp4
# Extracting features from Computer---v---vid-3984---lsid-10512.mp4
# Extracting features from Computer---t---vid-3988---lsid-10514.mp4
# Extracting features from Computer---Leonardo---vid-11451---lsid-15141.mp4
# Extracting features from Computer---Leonardo---vid-11447---lsid-15139.mp4
# Extracting features from Computer---noe-w-b---vid-3994---lsid-10517.mp4
# Extracting features from Computer---ooe-w-st---vid-3986---lsid-10513.mp4
# Extracting features from Dezember---noe---vid-12424---lsid-15824.mp4
# Extracting features from Dezember---v---vid-8800---lsid-12162.mp4
# Extracting features from Dezember---ooe---vid-2894---lsid-11829.mp4
# Extracting features from Dezember---OÖ-UK---vid-39778---lsid-33272.mp4
# Extracting features from Dezember---t---vid-4116---lsid-10582.mp4
# Extracting features from Dezember---k---vid-4114---lsid-10581.mp4
# Extracting features from Dezember---b---vid-4112---lsid-10580.mp4
# Extracting features from Dezember---w---vid-4110---lsid-10578.mp4
# Extracting features from Dezember---w---vid-4108---lsid-10577.mp4
# Extracting features from Dezember---st---vid-50432---lsid-37729.mp4
# Extracting features from Dezember---st-ogs---vid-43319---lsid-18414.mp4
# Extracting features from Dezember---noe---vid-12421---lsid-15823.mp4
# Extracting features from Dezember---w-v---vid-113---lsid-3794.mp4
# Extracting features from Dezember---ooe---vid-58444---lsid-40451.mp4
# Extracting features from Dezember---st---vid-2896---lsid-11830.mp4
# Extracting features from Dezember---s-k---vid-4106---lsid-10576.mp4
# Extracting features from Dezember---t---vid-15280---lsid-18415.mp4
# Extracting features from Dezember---t---vid-3416---lsid-10066.mp4
# Extracting features from Dezember---st---vid-2898---lsid-11831.mp4
# Extracting features from Banane---ooe---vid-20075---lsid-22589.mp4
# Extracting features from Banane---b---vid-3612---lsid-10250.mp4
# Extracting features from Banane---ogs---vid-28218---lsid-29566.mp4
# Extracting features from Banane---t-noe---vid-20078---lsid-22590.mp4
# Extracting features from Banane---t---vid-15376---lsid-18491.mp4
# Extracting features from Banane---Stmk_UK---vid-72442---lsid-44265.mp4
# Extracting features from Banane---w-st---vid-15952---lsid-16594.mp4
# Extracting features from Banane---v---vid-16837---lsid-18516.mp4
# Extracting features from Banane---v---vid-20068---lsid-22584.mp4
# Extracting features from Banane---s---vid-20071---lsid-22586.mp4
# Extracting features from Banane---s---vid-21290---lsid-22587.mp4
# Extracting features from Banane---k---vid-56876---lsid-40232.mp4
# Extracting features from Banane---w---vid-1896---lsid-5681.mp4
# Extracting features from Banane---ooe---vid-20073---lsid-22588.mp4
# Extracting features from Banane---ooe---vid-3610---lsid-10249.mp4
# Extracting features from Banane---w---vid-20069---lsid-22585.mp4
# Extracting features from Banane---w---vid-1898---lsid-5682.mp4
# Extracting features from Banane---k---vid-20079---lsid-22591.mp4
# Extracting features from Banane---OÖ-UK---vid-40599---lsid-33670.mp4
# Extracting features from Banane---OÖ-UK---vid-40601---lsid-33671.mp4
# Extracting features from K_uehlschrank---s---vid-16098---lsid-16687.mp4
# Extracting features from K_uehlschrank---ooe---vid-16633---lsid-20978.mp4
# Extracting features from K_uehlschrank---w-s-st---vid-48573---lsid-20981.mp4
# Extracting features from K_uehlschrank---ogs---vid-31448---lsid-30647.mp4
# Extracting features from K_uehlschrank---k---vid-16090---lsid-16683.mp4
# Extracting features from K_uehlschrank---st---vid-16099---lsid-16688.mp4
# Extracting features from K_uehlschrank---st---vid-16102---lsid-16689.mp4
# Extracting features from K_uehlschrank---w---vid-16631---lsid-20977.mp4
# Extracting features from K_uehlschrank---noe---vid-16091---lsid-16684.mp4
# Extracting features from K_uehlschrank---v---vid-16629---lsid-20975.mp4
# Extracting features from K_uehlschrank---v---vid-16104---lsid-16690.mp4
# Extracting features from K_uehlschrank---k---vid-63664---lsid-20980.mp4
# Extracting features from K_uehlschrank---t---vid-16625---lsid-20976.mp4
# Extracting features from K_uehlschrank---t---vid-223---lsid-3906.mp4
# Extracting features from K_uehlschrank---w---vid-221---lsid-3905.mp4
# Extracting features from K_uehlschrank---b-ogs---vid-36578---lsid-20979.mp4
# Extracting features from K_uehlschrank---OÖ-UK---vid-41429---lsid-34079.mp4
# Extracting features from K_uehlschrank---noe---vid-16094---lsid-16685.mp4
# Extracting features from K_uehlschrank---ooe-w---vid-16095---lsid-16686.mp4
# Extracting features from Loch---k---vid-71622---lsid-43977.mp4
# Extracting features from Loch---Oô-UK---vid-41504---lsid-34116.mp4
# Extracting features from Loch---s---vid-13363---lsid-17362.mp4
# Extracting features from Loch---k---vid-22708---lsid-22210.mp4
# Extracting features from Loch---v---vid-13353---lsid-17358.mp4
# Extracting features from Loch---w---vid-22677---lsid-22195.mp4
# Extracting features from Loch---st---vid-22663---lsid-22188.mp4
# Extracting features from Loch---st---vid-13368---lsid-17364.mp4
# Extracting features from Loch---b---vid-22687---lsid-22200.mp4
# Extracting features from Loch---v---vid-22668---lsid-22190.mp4
# Extracting features from Loch---w---vid-2418---lsid-4068.mp4
# Extracting features from Loch---w---vid-66597---lsid-42476.mp4
# Extracting features from Loch---ooe---vid-22693---lsid-22203.mp4
# Extracting features from Loch---w---vid-13366---lsid-17363.mp4
# Extracting features from Loch---s-st---vid-22665---lsid-22189.mp4
# Extracting features from Loch---k---vid-13376---lsid-17370.mp4
# Extracting features from Loch---t---vid-22671---lsid-22192.mp4
# Extracting features from Loch---t---vid-2420---lsid-4069.mp4
# Extracting features from wann---t---vid-1416---lsid-4631.mp4
# Extracting features from wann---v---vid-12765---lsid-17015.mp4
# Extracting features from wann---ooe---vid-12773---lsid-17019.mp4
# Extracting features from wann---s---vid-12777---lsid-17021.mp4
# Extracting features from wann---OÖ-UK---vid-40298---lsid-33522.mp4
# Extracting features from wann---ogs---vid-23438---lsid-24748.mp4
# Extracting features from wann---noe-s-k---vid-12757---lsid-17011.mp4
# Extracting features from wann---t-v---vid-1418---lsid-4632.mp4
# Extracting features from wann---st---vid-12753---lsid-17009.mp4
# Extracting features from wann---k---vid-23157---lsid-24349.mp4
# Extracting features from wann---noe-w-k---vid-52600---lsid-17022.mp4
# Extracting features from wann---v---vid-12767---lsid-17016.mp4
# Extracting features from wann---noe-st-k---vid-12755---lsid-17010.mp4
# Extracting features from wann---st---vid-12775---lsid-17020.mp4
# Extracting features from wann---ogs---vid-31192---lsid-30515.mp4
# Extracting features from wann---v---vid-12763---lsid-17014.mp4
# Extracting features from wann---t---vid-1414---lsid-4630.mp4
# Extracting features from wann---ooe---vid-12751---lsid-17008.mp4
# Extracting features from wann---s---vid-12759---lsid-17012.mp4
# Extracting features from wann---OÖ-UK---vid-40300---lsid-33523.mp4
# Extracting features from wann---Stmk_UK---vid-72962---lsid-44524.mp4
# Extracting features from wann---v---vid-12769---lsid-17017.mp4
# Extracting features from wann---w---vid-12761---lsid-17013.mp4
# Extracting features from wann---ooe-s---vid-12771---lsid-17018.mp4
# Extracting features from was---w---vid-12962---lsid-17136.mp4
# Extracting features from was---w---vid-12965---lsid-17138.mp4
# Extracting features from was---k---vid-12857---lsid-17065.mp4
# Extracting features from was---noe---vid-12943---lsid-17128.mp4
# Extracting features from was---t---vid-1430---lsid-4641.mp4
# Extracting features from was---k---vid-12897---lsid-17085.mp4
# Extracting features from was---noe---vid-12860---lsid-17066.mp4
# Extracting features from was---t---vid-1428---lsid-4640.mp4
# Extracting features from was---ooe---vid-12861---lsid-17067.mp4
# Extracting features from was---ooe---vid-12900---lsid-17086.mp4
# Extracting features from was---s---vid-12871---lsid-17072.mp4
# Extracting features from was---w---vid-12868---lsid-17070.mp4
# Extracting features from was---v---vid-12895---lsid-17084.mp4
# Extracting features from was---OÖ-UK---vid-40288---lsid-33517.mp4
# Extracting features from was---v---vid-12877---lsid-17075.mp4
# Extracting features from was---k---vid-54813---lsid-39586.mp4
# Extracting features from was---Stmk_UK---vid-72972---lsid-44529.mp4
# Extracting features from was---w---vid-12951---lsid-17131.mp4
# Extracting features from was---ogs---vid-31190---lsid-30514.mp4
# Extracting features from was---s---vid-12953---lsid-17132.mp4
# Extracting features from was---st---vid-12863---lsid-17068.mp4
# Extracting features from was---s---vid-12957---lsid-17134.mp4
# Extracting features from was---st---vid-12948---lsid-17129.mp4
# Extracting features from was---w---vid-12950---lsid-17130.mp4
# Extracting features from was---w---vid-12875---lsid-17074.mp4
