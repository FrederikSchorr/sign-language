# %%
import numpy as np
import pandas as pd

import os
import glob

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline

# %%
sLog = "../data/90-logs/20180510-1238-lstm-350in21.log"
dfLog = pd.read_csv(sLog)
dfLog.tail()
# Out:
#      epoch       acc      loss   val_acc  val_loss
# 995    995  0.872024  0.395425  0.328125  5.092454
# 996    996  0.830357  0.479429  0.328125  5.116946
# 997    997  0.854167  0.438470  0.304688  5.295996
# 998    998  0.836310  0.483369  0.296875  5.410496
# 999    999  0.809524  0.479920  0.334375  5.112384

# %%
plt.plot(dfLog.epoch, dfLog.acc, label="Training accuracy")
plt.plot(dfLog.epoch, dfLog.val_acc, label="Validation accuracy")

plt.ylim((0,1))
plt.legend()
plt.show()

# %%
plt.plot(dfLog.epoch, dfLog.loss, label="Training loss")
plt.plot(dfLog.epoch, dfLog.val_loss, label="Validation loss")

plt.legend()
plt.show()
